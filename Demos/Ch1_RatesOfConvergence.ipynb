# %% [markdown]
# <a href="https://colab.research.google.com/github/stephenbeckr/numerical-analysis-class/blob/master/Demos/Ch1_RatesOfConvergence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-ticks')
import matplotlib as mpl
mpl.rcParams['mathtext.fontset'] = 'cm'
# See plotting cheat-sheets at https://github.com/matplotlib/cheatsheets

n   = np.arange(1,1e3)

# %% [markdown]
# ## Convergence
# $x_n = 1/\sqrt{n}$ or $x_n = 1/n$ or $x_n = 1/n^2$ are all **sublinearly** convergent.  On a log-log plot, this is a straight line (and the slope gives us the exponent)
#
# $x_n = c^n$ for $|c|<1$ is **linearly** convergent  (on a log-linear plot, this is a straight line)
#
# $x_n = c^{d^n}$ is **quadratically** convergent (this looks like linear convergence, but then suddenly the error goes to zero extremely fast)

# %%
def makePlots( fcn, name):
  fig, axs = plt.subplots(1,4)
  fig.set_size_inches(16,4)
  for i in range(4):
    axs[i].plot( n,fcn(n),linewidth=2.0)
    axs[i].grid()
  axs[1].set_xscale('log')
  axs[2].set_yscale('log')
  axs[3].set_xscale('log')
  axs[3].set_yscale('log')
  fig.suptitle(name,fontsize=22);
makePlots( lambda n: 1/np.sqrt(n), r'$x_n = 1/\sqrt{n}$')
makePlots( lambda n: 1/n, r'$x_n = 1/n$')
makePlots( lambda n: 1/(n**2), r'$x_n = 1/n^2$')
makePlots( lambda n: .9**n, r'$x_n = .9^n$')
makePlots( lambda n: (.9)**(1.1**n), r'$x_n = .9^{1.1^n}$')

# %%
# Comparing the rates

fig, ax = plt.subplots()
ax.plot( n, 1/n, linewidth=2.0,label=r'$x_n = 1/n$')
ax.plot( n, .99**n, linewidth=2.0,label=r'$x_n = .99^n$')
ax.legend(fontsize=14,frameon=True)
ax.set_yscale('log')
fig.suptitle('Linear convergence is **asymptotically** faster than sub-linear convergence',fontsize=22);
